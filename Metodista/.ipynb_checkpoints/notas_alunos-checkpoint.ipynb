# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('notas_alunos.csv')
df
# Out:
#      Questao 1  Questao 2  Questao 3  Questao 4  Questao 5  Questao 6  \
# 0         0.50       0.75       0.55       0.75       0.50       0.50
# 1         0.40       0.70       0.70       1.00       0.45       0.45
# 2         0.30       0.65       0.75       0.80       0.40       0.40
# 3         0.20       0.60       0.70       0.90       0.45       0.40
# 4         0.45       0.45       0.75       0.85       0.50       0.50
# 5         0.50       0.75       0.55       0.75       0.50       0.50
# 6         0.40       0.70       0.70       1.00       0.45       0.45
# 7         0.30       0.65       0.75       0.80       0.40       0.40
# 8         0.20       0.60       0.70       0.90       0.45       0.40
# 9         0.45       0.45       0.75       0.85       0.50       0.50
# 10        0.30       0.65       0.75       0.80       0.40       0.40
# 11        0.20       0.60       0.70       0.90       0.45       0.40
# ...

# %%
df.index += 1

# %%
df.index.name='Alunos'

# %%
# Uma amostra das notas dos alunos tabelada
df
# Out:
#         Questao 1  Questao 2  Questao 3  Questao 4  Questao 5  Questao 6  \
# Alunos
# 1            0.50       0.75       0.55       0.75       0.50       0.50
# 2            0.40       0.70       0.70       1.00       0.45       0.45
# 3            0.30       0.65       0.75       0.80       0.40       0.40
# 4            0.20       0.60       0.70       0.90       0.45       0.40
# 5            0.45       0.45       0.75       0.85       0.50       0.50
# 6            0.50       0.75       0.55       0.75       0.50       0.50
# 7            0.40       0.70       0.70       1.00       0.45       0.45
# 8            0.30       0.65       0.75       0.80       0.40       0.40
# 9            0.20       0.60       0.70       0.90       0.45       0.40
# 10           0.45       0.45       0.75       0.85       0.50       0.50
# 11           0.30       0.65       0.75       0.80       0.40       0.40
# 12           0.20       0.60       0.70       0.90       0.45       0.40
# ...

# %%
#todos os alunos
pd.set_option("display.max_rows", None, "display.max_columns", None)
df
# Out:
#         Questao 1  Questao 2  Questao 3  Questao 4  Questao 5  Questao 6  \
# Alunos
# 1            0.50       0.75       0.55       0.75       0.50       0.50
# 2            0.40       0.70       0.70       1.00       0.45       0.45
# 3            0.30       0.65       0.75       0.80       0.40       0.40
# 4            0.20       0.60       0.70       0.90       0.45       0.40
# 5            0.45       0.45       0.75       0.85       0.50       0.50
# 6            0.50       0.75       0.55       0.75       0.50       0.50
# 7            0.40       0.70       0.70       1.00       0.45       0.45
# 8            0.30       0.65       0.75       0.80       0.40       0.40
# 9            0.20       0.60       0.70       0.90       0.45       0.40
# 10           0.45       0.45       0.75       0.85       0.50       0.50
# 11           0.30       0.65       0.75       0.80       0.40       0.40
# 12           0.20       0.60       0.70       0.90       0.45       0.40
# ...

# %%
#Calculo das notas => soma das notas
df['Nota Geral'] = df.sum(axis=1)

# %%
#Mostrando todas as notas
df
# Out:
#         Questao 1  Questao 2  Questao 3  Questao 4  Questao 5  Questao 6  \
# Alunos
# 1            0.50       0.75       0.55       0.75       0.50       0.50
# 2            0.40       0.70       0.70       1.00       0.45       0.45
# 3            0.30       0.65       0.75       0.80       0.40       0.40
# 4            0.20       0.60       0.70       0.90       0.45       0.40
# 5            0.45       0.45       0.75       0.85       0.50       0.50
# 6            0.50       0.75       0.55       0.75       0.50       0.50
# 7            0.40       0.70       0.70       1.00       0.45       0.45
# 8            0.30       0.65       0.75       0.80       0.40       0.40
# 9            0.20       0.60       0.70       0.90       0.45       0.40
# 10           0.45       0.45       0.75       0.85       0.50       0.50
# 11           0.30       0.65       0.75       0.80       0.40       0.40
# 12           0.20       0.60       0.70       0.90       0.45       0.40
# ...

# %%
#Media da turma
round(df['Nota Geral'].mean(), 2)
# Out:
# 8.46

# %%
#Variância
df['Nota Geral'].var()
# Out:
# 0.1996104051927614

# %%
#Desvio padrão
df['Nota Geral'].std()
# Out:
# 0.44677780293201835

# %%
#Há uma maneira mais resumida para ter vários dados já tabelados com informações estatísticas usando o describe()
df.describe()
# Out:
#         Questao 1   Questao 2   Questao 3   Questao 4   Questao 5   Questao 6  \
# count  124.000000  124.000000  124.000000  124.000000  124.000000  124.000000
# mean     0.355645    0.606855    0.701210    0.858871    0.460081    0.447177
# std      0.112114    0.104829    0.066706    0.075182    0.037709    0.046549
# min      0.200000    0.450000    0.550000    0.750000    0.400000    0.400000
# 25%      0.200000    0.450000    0.700000    0.800000    0.450000    0.400000
# 50%      0.400000    0.600000    0.700000    0.850000    0.450000    0.450000
# 75%      0.450000    0.700000    0.750000    0.900000    0.500000    0.500000
# max      0.500000    0.750000    0.750000    1.000000    0.500000    0.500000
#
#         Questao 7   Questao 8   Questao 9  Questao 10  Questao 11  Questao 12  \
# count  124.000000  124.000000  124.000000  124.000000  124.000000  124.000000
# mean     0.850806    0.460081    0.460081    0.460081    0.433226    0.390323
# ...

# %%
#Vamos verificar visualmente algumas destas informações
#a maior frequencia das notas fica entre 8.5 e ~8.8
df['Nota Geral'].hist(bins=4)
