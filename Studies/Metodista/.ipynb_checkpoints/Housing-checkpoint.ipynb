# %% [markdown]
# # Conteúdos e exercícios do livro Hand-On Machine Learning

# %% [markdown]
# ## LOADING DATA

# %%
import os
import tarfile
import urllib

import warnings
warnings.filterwarnings('ignore')

# %%
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join('datasets', 'housing')
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

# %%
def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    os.makedirs(housing_path, exist_ok=True)
    tgz_path = os.path.join(housing_path, 'housing.tgz')
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
fetch_housing_data()

# %%
import pandas as pd

# %%
def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, 'housing.csv')
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data()
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
20640-20433
# Out:
# 207

# %%
# ocean_proximity probably is a categorical attribute
housing['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# 1) the median income has been scaled. 1 unit x 10.000. I.e. 3 means $30.000,00 <br>
# 2) The housing median age and the median house value were also capped. If we need precise predictions, we have two options:<br>
# a) Collect proper labels for the districts whose labels were capped<br>
# b) Remove those districts from the training set (and test set)<br>
# 3) These attributes have very different scales.<br>
# 4) Many histograms are tail-heavy: they extend much farther to the right of the median than to the left. We will transforming these attributes later on to have more bell-shaped distributions.

# %% [markdown]
# TEMOS QUE CRIAR O 'TEST SET' ANTES DE OLHAR OS DADOS. O TEST NUNCA OLHAREMOS.

# %% [markdown]
# ## CRIANDO TEST SET

# %%
# Regra de 80/20 = 80 training data / 20 test data

# %%
import numpy as np

# %%
def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(housing, 0.2)
len(train_set)
# Out:
# 16512

# %%
len(test_set)
# Out:
# 4128

# %%
4128/(16512+4128)
# Out:
# 0.2

# %% [markdown]
# It's work, but it isn't the perfect solution. Over time, we will get to see the whole dataset. One solution is to save the test set on the first run and then load it in subsequent runs. Another option is to set the random number generator's seed (e.g. with np.random.seed(42)) before calling np.random.permutation()<br><br>
# But these solutions will break the next time we fetch an updated dataset.

# %% [markdown]
# It is a possible solution: compute a hash of each instance's identifier:

# %%
from zlib import crc32

def test_set_check(identifier, test_ratio):
    return crc32(np.int64(identifier)) & 0xffffffff < test_ratio * 2**32

def split_train_test_by_id(data, test_ratio, id_column):
    ids = data[id_column]
    in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio))
    return data.loc[~in_test_set], data.loc[in_test_set]

# %%
# the housing DS does not have an identifier column, we need to use the row index as the ID:
housing_with_id = housing.reset_index() # add an 'index' column

# %%
train_set, test_set = split_train_test_by_id(housing_with_id, 0.2, 'index')

# %%
test_set.shape
# Out:
# (4128, 11)

# %%
train_set.shape
# Out:
# (16512, 11)

# %% [markdown]
# Trying to use the most stable features, f.e., you could combine them into an ID like so (lat and long):

# %%
housing_with_id['id'] = housing['longitude'] * 1000 + housing['latitude']
train_set, test_set= split_train_test_by_id(housing_with_id, 0.2, 'id')

# %%
train_set.shape
# Out:
# (16322, 12)

# %%
test_set.shape
# Out:
# (4318, 12)

# %% [markdown]
# Scikit-Learn provides a few functions to split Datasets into multiple subsets in various ways. train_test_split() is the simplest function:

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %%
train_set.shape
# Out:
# (16512, 10)

# %%
test_set.shape
# Out:
# (4128, 10)

# %% [markdown]
# Try to maintaining the 'stratified sampling'. The test set is representative of the overall population? If we use purely random sampling, there is a chance of turn the test set skewed. It is important to have the sufficient number of representatives of that category in the dataset for training and testing.

# %% [markdown]
# Let's look to the income category attribute. It is important to have a sufficient number of instances in your dataset for each stratum. Let's create a category:

# %%
housing['income_cat'] = pd.cut(housing['median_income'],
                              bins = [0., 1.5, 3.0, 4.5, 6., np.inf],
                              labels=[1,2,3,4,5])

# %%
housing['income_cat'].hist()

# %% [markdown]
# Now, we are ready to do stratified sampling based on the income category:

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(housing, housing['income_cat']):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_test_set['income_cat'].value_counts() / len(strat_test_set)
# Out:
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114583
# 1    0.039729
# Name: income_cat, dtype: float64

# %%
housing['income_cat'].value_counts() / len(housing)
# Out:
# 3    0.350581
# 2    0.318847
# 4    0.176308
# 5    0.114438
# 1    0.039826
# Name: income_cat, dtype: float64

# %%
#removing the income_cat attribute so the data is back to its original state
for set_ in (strat_train_set, strat_test_set):
    set_.drop('income_cat', axis=1, inplace=True)

# %% [markdown]
# This is an often neglected but critical part of a Machine Learning project.

# %% [markdown]
# Let's to exploring the data:

# %% [markdown]
# ## Discover and Visualize the Data to gain Insights

# %%
#Let's create a copy so that we can play with it without harming the training set

housing = strat_train_set.copy()

# %%
# Visualizing Geographical Data

housing.plot(kind='scatter', x='longitude', y='latitude')

# %%
# Setting alpha to 0.1 to visualize the places where there is a high density of data points

housing.plot(kind='scatter', x='longitude', y='latitude', alpha=0.1)

# %% [markdown]
# We can see the high density areas, namely the Bay Area and around L.A. and San Diego

# %%
# Now, let's look at the housing prices, using a predefined color map (option cmap) called jet:

housing.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4,
            s=housing['population']/100, label='population', figsize=(10,7),
            c='median_house_value', cmap=plt.get_cmap('jet'), colorbar=True)
plt.legend();

# %% [markdown]
# The housing prices are very much related to the location (e.g. close to the ocean) and to the population density.

# %%
#Computing the Standard Correlation Coefficient (also called Pearson's r) between every pair of attributes:

corr_matrix = housing.corr()

# %%
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.687160
# total_rooms           0.135097
# housing_median_age    0.114110
# households            0.064506
# total_bedrooms        0.047689
# population           -0.026920
# longitude            -0.047432
# latitude             -0.142724
# Name: median_house_value, dtype: float64

# %%
# Another way to check this correlation:

from pandas.plotting import scatter_matrix

attributes = ['median_house_value', 'median_income', 'total_rooms', 'housing_median_age']
scatter_matrix(housing[attributes], figsize=(12,8));

# %%
# The most promising attribute to predict the median house value is the median income, 
# so let's zoom in on their correlation scatterplot: (MEDIAN_HOUSE_VALUE X MEDIAN_INCOME)

housing.plot(kind='scatter', x='median_income', y='median_house_value', alpha=0.1);

# %% [markdown]
# Existe uma tendência de alta. A correlação é muito forte. Tem um corte quando atinge 500k, outro perto de 350k e mais um aos 280k e alguns abaixo disso. Talvez queiramos remover estes distritos correspondentes para prevenir os algoritmos de aprender a reproduzir estes dados peculiares.

# %% [markdown]
# Try out various attribute combinations. For example, the total number of rooms in a district is not very useful if you
# dont know how many households there are. What you really want is the number of rooms per household. And population
# per household aso seems like an interesting attribute:

# %%
housing['rooms_per_household'] = housing['total_rooms']/housing['households']
housing['bedrooms_per_room'] = housing['total_bedrooms']/housing['total_rooms']
housing['population_per_household'] = housing['population']/housing['households']

# %%
corr_matrix = housing.corr()
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.687160
# rooms_per_household         0.146285
# total_rooms                 0.135097
# housing_median_age          0.114110
# households                  0.064506
# total_bedrooms              0.047689
# population_per_household   -0.021985
# population                 -0.026920
# longitude                  -0.047432
# latitude                   -0.142724
# bedrooms_per_room          -0.259984
# Name: median_house_value, dtype: float64

# %% [markdown]
# The new bedrooms_per_room attribute is much more correlated with the median house value than the total number of rooms or bedrooms.Apparentaly houses with a lower bedroom/room ratio tend to be more expensive.

# %% [markdown]
# ## Prepare the Data for Machine Learning Algorithms
